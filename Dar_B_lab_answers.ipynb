# %%
import pandas as pd
import numpy as np
dffile1 = pd.read_csv(r"C:\Users\Mi Notebook\Ironhack\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv")
dffile2 = pd.read_csv(r"C:\Users\Mi Notebook\Ironhack\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv")
dffile3 = pd.read_csv(r"C:\Users\Mi Notebook\Ironhack\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv")

# %%
dffile1.shape  #the shape of the first dataframe
# Out:
# (4008, 11)

# %%
dffile2.shape  #the shape of the second dataframe
# Out:
# (996, 11)

# %%
dffile3.shape  #the shape of the third dataframe
# Out:
# (7070, 11)

# %%
dffile1.columns  #just to check the initial look of the columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
#To standardise the header names
columns1 = []

for i in range (len(dffile1.columns)):
    columns1.append(dffile1.columns[i].lower().replace(" ","_"))
    
columns1
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
#To standardise the header names of file 2
columns2 = []

for i in range (len(dffile2.columns)):
    columns2.append(dffile2.columns[i].lower().replace(" ","_"))
    
columns2
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class']

# %%
#To standardise the header names of file 3
columns3 = []

for i in range (len(dffile3.columns)):
    columns3.append(dffile3.columns[i].lower().replace(" ","_"))
    
columns3
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
columns3[1] = 'st'
columns3
# Out:
# ['customer',
#  'st',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
#we replace the original column names with the standarized ones
dffile1.columns = columns1
dffile2.columns = columns2
dffile3.columns = columns3

# %%
dffile1.head() #  justo check the column names
# Out:
#   customer          st gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
dffile2.head() #  justo check the column names
# Out:
#   customer          st gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
dffile3.head() #  justo check the column names
# Out:
#   customer          st  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total_claim_amount  vehicle_class
# ...

# %%
# to concatenate the three dataframes
df_final = pd.concat([dffile1, dffile2, dffile3], axis = 0)
df_final.shape
# Out:
# (12074, 11)

# %%
#to understand the meaning of all columns
df_final.describe(include = "all")
# Out:
#        customer          st gender education  customer_lifetime_value  \
# count      9137        9137   9015      9137               9130.00000
# unique     9056           8      5         6               8211.00000
# top     QD28391  California      F  Bachelor              16468.22079
# freq          2        3032   4560      2719                  6.00000
# mean        NaN         NaN    NaN       NaN                      NaN
# std         NaN         NaN    NaN       NaN                      NaN
# min         NaN         NaN    NaN       NaN                      NaN
# 25%         NaN         NaN    NaN       NaN                      NaN
# 50%         NaN         NaN    NaN       NaN                      NaN
# 75%         NaN         NaN    NaN       NaN                      NaN
# max         NaN         NaN    NaN       NaN                      NaN
#
#               income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
#To delete the columns education and the number of open complaints
temp = df_final.copy()
temp.drop(['education', 'number_of_open_complaints'], axis = 1, inplace = True)
temp
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
# To check the number of null values
temp.isna().sum()
# Out:
# customer                   2937
# st                         2937
# gender                     3059
# customer_lifetime_value    2944
# income                     2937
# monthly_premium_auto       2937
# policy_type                2937
# vehicle_class              2937
# total_claim_amount         2937
# dtype: int64

# %%
# Proportion of null values
temp.isna().sum()/len(temp)
# Out:
# customer                   0.243250
# st                         0.243250
# gender                     0.253354
# customer_lifetime_value    0.243830
# income                     0.243250
# monthly_premium_auto       0.243250
# policy_type                0.243250
# vehicle_class              0.243250
# total_claim_amount         0.243250
# dtype: float64

# %%
# Shows the percentage of null values in a column
round(temp.isna().sum()/len(temp),4)*100
# Out:
# customer                   24.32
# st                         24.32
# gender                     25.34
# customer_lifetime_value    24.38
# income                     24.32
# monthly_premium_auto       24.32
# policy_type                24.32
# vehicle_class              24.32
# total_claim_amount         24.32
# dtype: float64

# %%
# to check for duplicates and remove them:
temp.shape
# Out:
# (12074, 9)

# %%
temp = temp.drop_duplicates()
temp.shape
# Out:
# (9135, 9)

# %%
temp
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
# to filter out the data for customers who have an income of 0 or less.
income_temp = temp[temp['income'] <= 0]

income_temp
# Out:
#      customer          st gender customer_lifetime_value  income  \
# 0     RB50392  Washington    NaN                     NaN     0.0
# 1     QZ44356     Arizona      F              697953.59%     0.0
# 3     WW63253  California      M              764586.18%     0.0
# 7     CF85061     Arizona      M              721610.03%     0.0
# 10    SX51350  California      M              473899.20%     0.0
# ...       ...         ...    ...                     ...     ...
# 7059  WZ45103  California      F             5678.050167     0.0
# 7061  RX91025  California      M               19872.262     0.0
# 7062  AC13887  California      M             4628.995325     0.0
# 7067  TD14365  California      M             8163.890428     0.0
# 7069  Y167826  California      M             2611.836866     0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
